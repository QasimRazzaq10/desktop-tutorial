# %%
import pandas as pd

# %%
import matplotlib as plt
df=pd.read_csv("Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.head(4)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0

# %%
df.tail(2)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.sample(6)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 1658              9               52                        Yes            7
# 4627              4               97                        Yes            5
# 7366              7               51                         No            9
# 9041              8               70                         No            8
# 7153              6               74                        Yes            4
# 7587              3               41                         No            9
#
#       Sample Question Papers Practiced  Performance Index
# 1658                                 6               52.0
# 4627                                 5               80.0
# 7366                                 3               44.0
# 9041                                 5               61.0
# 7153                                 2               63.0
# 7587                                 1               22.0

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.rename(columns={"Hours Studied":"study hours","Sleep Hours":"Hours sleep"})
# Out:
#       study hours  Previous Scores Extracurricular Activities  Hours sleep  \
# 0               7               99                        Yes            9
# 1               4               82                         No            4
# 2               8               51                        Yes            7
# 3               5               52                        Yes            5
# 4               7               75                         No            8
# ...           ...              ...                        ...          ...
# 9995            1               49                        Yes            4
# 9996            7               64                        Yes            8
# 9997            6               83                        Yes            8
# 9998            9               97                        Yes            7
# 9999            7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# ...

# %%
pd.set_option=("display.max_rows",None)
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.describe(include="all")
# Out:
#         Hours Studied  Previous Scores Extracurricular Activities  \
# count    10000.000000     10000.000000                      10000
# unique            NaN              NaN                          2
# top               NaN              NaN                         No
# freq              NaN              NaN                       5052
# mean         4.992900        69.445700                        NaN
# std          2.589309        17.343152                        NaN
# min          1.000000        40.000000                        NaN
# 25%          3.000000        54.000000                        NaN
# 50%          5.000000        69.000000                        NaN
# 75%          7.000000        85.000000                        NaN
# max          9.000000        99.000000                        NaN
#
#          Sleep Hours  Sample Question Papers Practiced  Performance Index
# count   10000.000000                      10000.000000       10000.000000
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df["Previous Scores"].plot(kind="line")
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.fillna(55)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
print(df.duplicated)
# Out:
# <bound method DataFrame.duplicated of       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df["Performance Index"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Performance Index'>

# %%
df["Performance Index"].plot(kind="line")
# Out:
# <Axes: >

# %%
df["Performance Index"].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Performance Index"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Performance Index"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Performance Index'>

# %%
df["Performance Index"].value_counts().plot(kind="line",color="red")
# Out:
# <Axes: xlabel='Performance Index'>

# %%
df.plot(color="black")
# Out:
# <Axes: >

# %%
df["Performance Index"].std()
# Out:
# 19.212557799463323

# %%
df.isnull()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0             False            False                       False        False
# 1             False            False                       False        False
# 2             False            False                       False        False
# 3             False            False                       False        False
# 4             False            False                       False        False
# ...             ...              ...                         ...          ...
# 9995          False            False                       False        False
# 9996          False            False                       False        False
# 9997          False            False                       False        False
# 9998          False            False                       False        False
# 9999          False            False                       False        False
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df[df["Hours Studied"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Hours Studied, Previous Scores, Extracurricular Activities, Sleep Hours, Sample Question Papers Practiced, Performance Index]
# Index: []

# %%
df["Hours Studied"]=df["Hours Studied"].fillna(df["Hours Studied"].mean())

# %%
df[df["Hours Studied"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Hours Studied, Previous Scores, Extracurricular Activities, Sleep Hours, Sample Question Papers Practiced, Performance Index]
# Index: []

# %%
df.loc[[2,4,5,6]]
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 2              8               51                        Yes            7
# 4              7               75                         No            8
# 5              3               78                         No            9
# 6              7               73                        Yes            5
#
#    Sample Question Papers Practiced  Performance Index
# 2                                 2               45.0
# 4                                 5               66.0
# 5                                 6               61.0
# 6                                 6               63.0

# %%
df.iloc[[2,3]]
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
#
#    Sample Question Papers Practiced  Performance Index
# 2                                 2               45.0
# 3                                 2               36.0

# %%
df.groupby("Previous Scores").describe()
# Out:
#                 Hours Studied                                                \
#                         count      mean       std  min  25%  50%   75%  max
# Previous Scores
# 40                      173.0  4.826590  2.593370  1.0  3.0  5.0  7.00  9.0
# 41                      169.0  5.289941  2.642141  1.0  3.0  5.0  8.00  9.0
# 42                      171.0  4.906433  2.596947  1.0  2.5  5.0  7.00  9.0
# 43                      167.0  5.101796  2.633507  1.0  3.0  5.0  7.00  9.0
# 44                      170.0  5.094118  2.581791  1.0  3.0  5.0  7.00  9.0
# 45                      154.0  5.292208  2.636906  1.0  3.0  6.0  8.00  9.0
# 46                      163.0  4.901840  2.660211  1.0  3.0  5.0  7.00  9.0
# 47                      172.0  5.412791  2.494077  1.0  3.0  6.0  7.00  9.0
# 48                      170.0  4.735294  2.603012  1.0  3.0  5.0  7.00  9.0
# 49                      175.0  4.811429  2.646595  1.0  3.0  5.0  7.00  9.0
# ...

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
df.fillna(12)
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.dropna()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df[2:5]
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df[1:7:2]
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 1              4               82                         No            4
# 3              5               52                        Yes            5
# 5              3               78                         No            9
#
#    Sample Question Papers Practiced  Performance Index
# 1                                 2               65.0
# 3                                 2               36.0
# 5                                 6               61.0

# %%
kind="bar"

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
df["Hours Studied"].mean()
# Out:
# 4.9929

# %%
df["Previous Scores"].median()
# Out:
# 69.0

# %%
df["Sample Question Papers Practiced"].mode()
# Out:
# 0    6
# Name: Sample Question Papers Practiced, dtype: int64

# %%
b=df[["Sample Question Papers Practiced","Performance Index"]]
b
# Out:
#       Sample Question Papers Practiced  Performance Index
# 0                                    1               91.0
# 1                                    2               65.0
# 2                                    2               45.0
# 3                                    2               36.0
# 4                                    5               66.0
# ...                                ...                ...
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0
#
# [10000 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
x = df["Performance Index"].fillna(800)

# %%
x = df
